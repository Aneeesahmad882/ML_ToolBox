# %% [raw]
# #Answer1
# Matplotlib is a popular Python library for data visualization. It provides a wide variety of plotting options and can be used to create high-quality static, animated, and interactive plots in Python.
#
# People use Matplotlib to visually represent data in a meaningful way, making it easier to understand patterns, trends, and relationships in the data. It's widely used in fields like data science, machine learning, finance, and scientific research.
#
# As for five plots you can create using the Pyplot module of Matplotlib:
#
# 1-Line Plot: Use plt.plot() to create a basic line plot, suitable for visualizing trends over a continuous variable.
#
# 2-Scatter Plot: You can use plt.scatter() to create scatter plots, which are useful for visualizing the relationship between two continuous variables.
#
# 3-Bar Plot: plt.bar() is handy for comparing values across different categories. It's great for showing comparisons or distributions.
#
# 4-Histogram: Use plt.hist() to create histograms, which are useful for visualizing the distribution of a single variable.
#
# 5-Pie Chart: plt.pie() allows you to create pie charts, useful for representing parts of a whole or proportions.
#
# These are just a few examples, and Matplotlib offers many more types of plots for various purposes.
# It's a versatile tool for exploring and presenting data visually.

# %% [raw]
# #Answer2
# Scatter Plot: You can use plt.scatter() to create scatter plots, which are useful for visualizing the relationship between two continuous variables.

# %%
#scatter plot
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("This is my title")
plt.scatter(x,y)
plt.show()

# %% [raw]
# #Answer3
# The subplot() function in Matplotlib is used to create multiple plots within the same figure.
# It allows you to arrange subplots in a grid, specifying the number of rows and columns.
# This is useful when you want to compare or visualize different aspects of your data side by side

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for line plots
x = np.array([0, 1, 2, 3, 4, 5])

y1 = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3 = np.array([10, 20, 30, 40, 50, 60])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots in a 2x2 grid
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [raw]
# #Answer4
# A bar plot (or bar chart) is a type of chart that presents categorical data with rectangular bars. The lengths of the bars are proportional to the values they represent. Bar plots are useful for comparing the values of different categories and showing the distribution or relationship between them.
#
# Now, let's create a bar plot and a horizontal bar plot using the provided data:

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Bar plot
plt.figure(figsize=(8, 5))
plt.bar(company, profit, color='skyblue')
plt.title('Profit of Companies')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

# Horizontal bar plot
plt.figure(figsize=(8, 5))
plt.barh(company, profit, color='salmon')
plt.title('Profit of Companies (Horizontal)')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [raw]
# #Answer5
# A box plot (or box-and-whisker plot) is a statistical visualization method that displays the distribution of a dataset.
# It shows the summary statistics of a set of data, including the minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
# Additionally, it can reveal potential outliers in the data.
#
# Here's how you can create a box plot using the provided data:

# %%
import numpy as np
import matplotlib.pyplot as plt

box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Combine the two datasets into a list
data = [box1, box2]

# Create a box plot
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.title('Box Plot of Two Datasets')
plt.ylabel('Values')

# Show the plot
plt.show()
